# %%
#Import dependencies
import pandas as pd
import matplotlib as plt
import numpy as np

# Import the API key.
from config import weather_api_key

# %%
# 3 Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# 4 Get the nearest city using the citipy module.

#Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

#Create a list for holding the cities
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 762

# %%
#Import dependencies
from config import weather_api_key

# 5 Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 6 Retrieve the following information from the API call:
        # Latitude and longitude
        # Maximum temperature
        # Percent humidity
        # Percent cloudiness
        # Wind speed
        # Weather description (for example, clouds, fog, light rain, clear sky)
        
#Import dependencies
import requests

#Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#Loop through all the cities in our list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count
    record_count += 1

#Run an API request for each of the cites 
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        #Parse out the needed data
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        #Append the city information into city_data list
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat, 
                          'Lng': city_lng, 
                          'Max Temp': city_max_temp, 
                          'Humidity': city_humidity, 
                          'Cloudiness': city_clouds, 
                          'Wind Speed': city_wind, 
                          'Current Description': city_description})
        
#If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

#Indicate that the Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | kirakira
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | whitehorse
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | kahului
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | sarana
# Processing Record 11 of Set 1 | sao jose do rio preto
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | provideniya
# Processing Record 15 of Set 1 | matamoros
# Processing Record 16 of Set 1 | yulara
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | jacareacanga
# Processing Record 21 of Set 1 | camacha
# Processing Record 22 of Set 1 | san quintin
# Processing Record 23 of Set 1 | hirara
# Processing Record 24 of Set 1 | esperance
# Processing Record 25 of Set 1 | natitingou
# Processing Record 26 of Set 1 | quesnel
# Processing Record 27 of Set 1 | khatanga
# Processing Record 28 of Set 1 | lebu
# Processing Record 29 of Set 1 | vardo
# Processing Record 30 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 1 | nyandoma
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | torbat-e jam
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | buchanan
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | pedro carbo
# Processing Record 39 of Set 1 | owando
# Processing Record 40 of Set 1 | new norfolk
# Processing Record 41 of Set 1 | henties bay
# Processing Record 42 of Set 1 | kodiak
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | faanui
# Processing Record 4 of Set 2 | qui nhon
# Processing Record 5 of Set 2 | luderitz
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | klaksvik
# Processing Record 8 of Set 2 | mahebourg
# Processing Record 9 of Set 2 | vila velha
# Processing Record 10 of Set 2 | najran
# Processing Record 11 of Set 2 | acapulco
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | sao miguel do araguaia
# Processing Record 14 of Set 2 | makat
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | arman
# Processing Record 17 of Set 2 | chokurdakh
# Processing Record 18 of Set 2 | ozernovskiy
# Processing Record 19 of Set 2 | evensk
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | rivadavia
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 2 | vaini
# Processing Record 25 of Set 2 | torbay
# Processing Record 26 of Set 2 | skegness
# Processing Record 27 of Set 2 | paytug
# City not found. Skipping...
# Processing Record 28 of Set 2 | xixiang
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | ahuimanu
# Processing Record 31 of Set 2 | tungor
# Processing Record 32 of Set 2 | krutinka
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | namatanai
# Processing Record 35 of Set 2 | pacific grove
# Processing Record 36 of Set 2 | cherskiy
# Processing Record 37 of Set 2 | acarau
# Processing Record 38 of Set 2 | lasa
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | mackay
# Processing Record 41 of Set 2 | cabo san lucas
# Processing Record 42 of Set 2 | kolimvari
# City not found. Skipping...
# Processing Record 43 of Set 2 | santiago de cao
# Processing Record 44 of Set 2 | nuqui
# Processing Record 45 of Set 2 | puerto colombia
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | mumford
# Processing Record 48 of Set 2 | jaru
# Processing Record 49 of Set 2 | ahipara
# Processing Record 50 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 3 | saint marys
# Processing Record 2 of Set 3 | naze
# Processing Record 3 of Set 3 | mozarlandia
# Processing Record 4 of Set 3 | adrar
# Processing Record 5 of Set 3 | hede
# Processing Record 6 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 3 | pangai
# Processing Record 8 of Set 3 | durban
# Processing Record 9 of Set 3 | ponta delgada
# Processing Record 10 of Set 3 | novocheremshansk
# Processing Record 11 of Set 3 | piacabucu
# Processing Record 12 of Set 3 | egvekinot
# Processing Record 13 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 14 of Set 3 | portland
# Processing Record 15 of Set 3 | tartki
# City not found. Skipping...
# Processing Record 16 of Set 3 | kamenka
# Processing Record 17 of Set 3 | awbari
# Processing Record 18 of Set 3 | inta
# Processing Record 19 of Set 3 | port hawkesbury
# Processing Record 20 of Set 3 | garmsar
# Processing Record 21 of Set 3 | port lincoln
# Processing Record 22 of Set 3 | winkler
# Processing Record 23 of Set 3 | codrington
# Processing Record 24 of Set 3 | arraial do cabo
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | ongandjera
# Processing Record 27 of Set 3 | bonthe
# Processing Record 28 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 3 | geraldton
# Processing Record 30 of Set 3 | nantucket
# Processing Record 31 of Set 3 | labuhan
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 3 | tiarei
# Processing Record 35 of Set 3 | fukue
# Processing Record 36 of Set 3 | port hardy
# Processing Record 37 of Set 3 | chimbote
# Processing Record 38 of Set 3 | kloulklubed
# Processing Record 39 of Set 3 | neiafu
# Processing Record 40 of Set 3 | qinhuangdao
# Processing Record 41 of Set 3 | oriximina
# Processing Record 42 of Set 3 | maneadero
# Processing Record 43 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 3 | yamada
# Processing Record 46 of Set 3 | victoria
# Processing Record 47 of Set 3 | jinxiang
# Processing Record 48 of Set 3 | sambava
# Processing Record 49 of Set 3 | qaanaaq
# Processing Record 50 of Set 3 | severo-kurilsk
# Processing Record 1 of Set 4 | ekhabi
# Processing Record 2 of Set 4 | palamos
# Processing Record 3 of Set 4 | bababe
# City not found. Skipping...
# Processing Record 4 of Set 4 | barsovo
# Processing Record 5 of Set 4 | pevek
# Processing Record 6 of Set 4 | mbaiki
# Processing Record 7 of Set 4 | krasnyy kholm
# Processing Record 8 of Set 4 | nome
# Processing Record 9 of Set 4 | tual
# Processing Record 10 of Set 4 | san cristobal
# Processing Record 11 of Set 4 | flinders
# Processing Record 12 of Set 4 | pisco
# Processing Record 13 of Set 4 | puerto del rosario
# Processing Record 14 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 4 | broome
# Processing Record 16 of Set 4 | tiksi
# Processing Record 17 of Set 4 | kamaishi
# Processing Record 18 of Set 4 | mbandaka
# Processing Record 19 of Set 4 | port moresby
# Processing Record 20 of Set 4 | half moon bay
# Processing Record 21 of Set 4 | georgetown
# Processing Record 22 of Set 4 | avarua
# Processing Record 23 of Set 4 | saskylakh
# Processing Record 24 of Set 4 | olinda
# Processing Record 25 of Set 4 | hobyo
# Processing Record 26 of Set 4 | husavik
# Processing Record 27 of Set 4 | lavrentiya
# Processing Record 28 of Set 4 | itarema
# Processing Record 29 of Set 4 | palencia
# Processing Record 30 of Set 4 | aksu
# Processing Record 31 of Set 4 | lakes entrance
# Processing Record 32 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 4 | airai
# Processing Record 34 of Set 4 | brooks
# Processing Record 35 of Set 4 | chara
# Processing Record 36 of Set 4 | hay river
# Processing Record 37 of Set 4 | constitucion
# Processing Record 38 of Set 4 | talnakh
# Processing Record 39 of Set 4 | bilibino
# Processing Record 40 of Set 4 | saldanha
# Processing Record 41 of Set 4 | bukama
# Processing Record 42 of Set 4 | flin flon
# Processing Record 43 of Set 4 | burns lake
# Processing Record 44 of Set 4 | port-gentil
# Processing Record 45 of Set 4 | broken hill
# Processing Record 46 of Set 4 | paamiut
# Processing Record 47 of Set 4 | asayita
# City not found. Skipping...
# Processing Record 48 of Set 4 | juba
# Processing Record 49 of Set 4 | fort nelson
# Processing Record 50 of Set 4 | wittenheim
# Processing Record 1 of Set 5 | buenaventura
# Processing Record 2 of Set 5 | pedernales
# Processing Record 3 of Set 5 | maniitsoq
# Processing Record 4 of Set 5 | kaohsiung
# Processing Record 5 of Set 5 | alofi
# Processing Record 6 of Set 5 | biltine
# Processing Record 7 of Set 5 | high prairie
# Processing Record 8 of Set 5 | micomeseng
# Processing Record 9 of Set 5 | mount gambier
# Processing Record 10 of Set 5 | ha tinh
# Processing Record 11 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 12 of Set 5 | ibipeba
# Processing Record 13 of Set 5 | hithadhoo
# Processing Record 14 of Set 5 | soyo
# Processing Record 15 of Set 5 | cayenne
# Processing Record 16 of Set 5 | tawang
# Processing Record 17 of Set 5 | cabedelo
# Processing Record 18 of Set 5 | morden
# Processing Record 19 of Set 5 | milkovo
# Processing Record 20 of Set 5 | rio grande
# Processing Record 21 of Set 5 | guarapari
# Processing Record 22 of Set 5 | bandipur
# Processing Record 23 of Set 5 | sarankhola
# Processing Record 24 of Set 5 | borovichi
# Processing Record 25 of Set 5 | moerai
# Processing Record 26 of Set 5 | hilo
# Processing Record 27 of Set 5 | xam nua
# Processing Record 28 of Set 5 | kavaratti
# Processing Record 29 of Set 5 | takoradi
# Processing Record 30 of Set 5 | ler
# Processing Record 31 of Set 5 | hualmay
# Processing Record 32 of Set 5 | daphne
# Processing Record 33 of Set 5 | fare
# Processing Record 34 of Set 5 | dudinka
# Processing Record 35 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 5 | komsomolskiy
# Processing Record 37 of Set 5 | noumea
# Processing Record 38 of Set 5 | lompoc
# Processing Record 39 of Set 5 | iqaluit
# Processing Record 40 of Set 5 | acopiara
# Processing Record 41 of Set 5 | ambulu
# Processing Record 42 of Set 5 | vadso
# Processing Record 43 of Set 5 | byron bay
# Processing Record 44 of Set 5 | bereda
# Processing Record 45 of Set 5 | monteagudo
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 48 of Set 5 | tasiilaq
# Processing Record 49 of Set 5 | tuatapere
# Processing Record 50 of Set 5 | steinbach
# Processing Record 1 of Set 6 | yar-sale
# Processing Record 2 of Set 6 | sistranda
# Processing Record 3 of Set 6 | dinsor
# City not found. Skipping...
# Processing Record 4 of Set 6 | lorengau
# Processing Record 5 of Set 6 | bure
# Processing Record 6 of Set 6 | kaniama
# Processing Record 7 of Set 6 | leningradskiy
# Processing Record 8 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 6 | klenovyy
# Processing Record 10 of Set 6 | nuuk
# Processing Record 11 of Set 6 | ostersund
# Processing Record 12 of Set 6 | roald
# Processing Record 13 of Set 6 | alasehir
# Processing Record 14 of Set 6 | frutigen
# Processing Record 15 of Set 6 | clyde river
# Processing Record 16 of Set 6 | hamilton
# Processing Record 17 of Set 6 | port blair
# Processing Record 18 of Set 6 | iracoubo
# Processing Record 19 of Set 6 | nishihara
# Processing Record 20 of Set 6 | svelgen
# Processing Record 21 of Set 6 | taltal
# Processing Record 22 of Set 6 | mizpe ramon
# City not found. Skipping...
# Processing Record 23 of Set 6 | ust-kuyga
# Processing Record 24 of Set 6 | laguna
# Processing Record 25 of Set 6 | katangi
# Processing Record 26 of Set 6 | klyuchi
# Processing Record 27 of Set 6 | bonfim
# Processing Record 28 of Set 6 | ancud
# Processing Record 29 of Set 6 | odweyne
# Processing Record 30 of Set 6 | comodoro rivadavia
# Processing Record 31 of Set 6 | bethel
# Processing Record 32 of Set 6 | russell
# Processing Record 33 of Set 6 | salinas
# Processing Record 34 of Set 6 | saint anthony
# Processing Record 35 of Set 6 | teeli
# Processing Record 36 of Set 6 | rincon
# Processing Record 37 of Set 6 | calhoun
# Processing Record 38 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 6 | lazaro cardenas
# Processing Record 40 of Set 6 | parfenyevo
# Processing Record 41 of Set 6 | bathsheba
# Processing Record 42 of Set 6 | nova vicosa
# Processing Record 43 of Set 6 | norman wells
# Processing Record 44 of Set 6 | college
# Processing Record 45 of Set 6 | maragogi
# Processing Record 46 of Set 6 | port elizabeth
# Processing Record 47 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 48 of Set 6 | rosignol
# Processing Record 49 of Set 6 | kashary
# Processing Record 50 of Set 6 | isny
# Processing Record 1 of Set 7 | christchurch
# Processing Record 2 of Set 7 | staroutkinsk
# Processing Record 3 of Set 7 | sao joao da barra
# Processing Record 4 of Set 7 | kyshtovka
# Processing Record 5 of Set 7 | valparaiso
# Processing Record 6 of Set 7 | chuy
# Processing Record 7 of Set 7 | hope
# Processing Record 8 of Set 7 | nokaneng
# Processing Record 9 of Set 7 | havre-saint-pierre
# Processing Record 10 of Set 7 | mehamn
# Processing Record 11 of Set 7 | asau
# Processing Record 12 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 7 | sand springs
# Processing Record 14 of Set 7 | alice springs
# Processing Record 15 of Set 7 | aleksandrovsk-sakhalinskiy
# Processing Record 16 of Set 7 | mitsamiouli
# Processing Record 17 of Set 7 | roma
# Processing Record 18 of Set 7 | chistogorskiy
# Processing Record 19 of Set 7 | lawrenceburg
# Processing Record 20 of Set 7 | warman
# Processing Record 21 of Set 7 | fort myers beach
# Processing Record 22 of Set 7 | zapolyarnyy
# Processing Record 23 of Set 7 | shieli
# Processing Record 24 of Set 7 | mareeba
# Processing Record 25 of Set 7 | stornoway
# Processing Record 26 of Set 7 | bac lieu
# Processing Record 27 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 7 | wattens
# Processing Record 29 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 7 | bubaque
# Processing Record 31 of Set 7 | pochutla
# Processing Record 32 of Set 7 | freeport
# Processing Record 33 of Set 7 | igarka
# Processing Record 34 of Set 7 | ukiah
# Processing Record 35 of Set 7 | monrovia
# Processing Record 36 of Set 7 | tura
# Processing Record 37 of Set 7 | abha
# Processing Record 38 of Set 7 | bara
# Processing Record 39 of Set 7 | notre-dame-du-lac
# Processing Record 40 of Set 7 | los llanos de aridane
# Processing Record 41 of Set 7 | umm lajj
# Processing Record 42 of Set 7 | bracebridge
# Processing Record 43 of Set 7 | kaka
# Processing Record 44 of Set 7 | gazojak
# Processing Record 45 of Set 7 | mandurah
# Processing Record 46 of Set 7 | carauari
# Processing Record 47 of Set 7 | marawi
# Processing Record 48 of Set 7 | rocha
# Processing Record 49 of Set 7 | avera
# Processing Record 50 of Set 7 | dingle
# Processing Record 1 of Set 8 | zhezkazgan
# Processing Record 2 of Set 8 | hirado
# Processing Record 3 of Set 8 | ilulissat
# Processing Record 4 of Set 8 | mizque
# Processing Record 5 of Set 8 | podyuga
# Processing Record 6 of Set 8 | oranjemund
# Processing Record 7 of Set 8 | wewak
# Processing Record 8 of Set 8 | turukhansk
# Processing Record 9 of Set 8 | beloha
# Processing Record 10 of Set 8 | coihaique
# Processing Record 11 of Set 8 | salalah
# Processing Record 12 of Set 8 | vila franca do campo
# Processing Record 13 of Set 8 | booue
# Processing Record 14 of Set 8 | rossland
# Processing Record 15 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 8 | ulaanbaatar
# Processing Record 17 of Set 8 | ponta do sol
# Processing Record 18 of Set 8 | maua
# Processing Record 19 of Set 8 | soltsy
# Processing Record 20 of Set 8 | aykhal
# Processing Record 21 of Set 8 | ribeira grande
# Processing Record 22 of Set 8 | verkhoyansk
# Processing Record 23 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 8 | vila do maio
# Processing Record 25 of Set 8 | mansa
# Processing Record 26 of Set 8 | upernavik
# Processing Record 27 of Set 8 | cidreira
# Processing Record 28 of Set 8 | san miguel
# Processing Record 29 of Set 8 | kavieng
# Processing Record 30 of Set 8 | bima
# Processing Record 31 of Set 8 | carroll
# Processing Record 32 of Set 8 | miri
# Processing Record 33 of Set 8 | olafsvik
# Processing Record 34 of Set 8 | ulaangom
# Processing Record 35 of Set 8 | souillac
# Processing Record 36 of Set 8 | madan
# Processing Record 37 of Set 8 | hambantota
# Processing Record 38 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 8 | miyazu
# Processing Record 40 of Set 8 | huanren
# Processing Record 41 of Set 8 | muisne
# Processing Record 42 of Set 8 | rawson
# Processing Record 43 of Set 8 | kondinskoye
# Processing Record 44 of Set 8 | vrbove
# Processing Record 45 of Set 8 | rabo de peixe
# Processing Record 46 of Set 8 | alyangula
# Processing Record 47 of Set 8 | mayo
# Processing Record 48 of Set 8 | olean
# Processing Record 49 of Set 8 | charyshskoye
# Processing Record 50 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 9 | cabatuan
# Processing Record 2 of Set 9 | hillsborough
# Processing Record 3 of Set 9 | hasaki
# Processing Record 4 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 9 | pangkalanbuun
# Processing Record 6 of Set 9 | makakilo city
# Processing Record 7 of Set 9 | lagoa
# Processing Record 8 of Set 9 | lata
# Processing Record 9 of Set 9 | koforidua
# Processing Record 10 of Set 9 | te anau
# Processing Record 11 of Set 9 | cockburn town
# Processing Record 12 of Set 9 | sitka
# Processing Record 13 of Set 9 | nouadhibou
# Processing Record 14 of Set 9 | westport
# Processing Record 15 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 16 of Set 9 | tuim
# Processing Record 17 of Set 9 | ranong
# Processing Record 18 of Set 9 | puerto madryn
# Processing Record 19 of Set 9 | tecoanapa
# Processing Record 20 of Set 9 | mahon
# Processing Record 21 of Set 9 | aasiaat
# Processing Record 22 of Set 9 | mandalgovi
# Processing Record 23 of Set 9 | medveditskiy
# Processing Record 24 of Set 9 | san patricio
# Processing Record 25 of Set 9 | moura
# Processing Record 26 of Set 9 | kalevala
# Processing Record 27 of Set 9 | kinanah
# City not found. Skipping...
# Processing Record 28 of Set 9 | temple
# Processing Record 29 of Set 9 | pechory
# Processing Record 30 of Set 9 | luoyang
# Processing Record 31 of Set 9 | burica
# City not found. Skipping...
# Processing Record 32 of Set 9 | obo
# Processing Record 33 of Set 9 | mindelo
# Processing Record 34 of Set 9 | honiara
# Processing Record 35 of Set 9 | atar
# Processing Record 36 of Set 9 | boguchany
# Processing Record 37 of Set 9 | fortuna
# Processing Record 38 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 9 | arlit
# Processing Record 40 of Set 9 | dalbandin
# Processing Record 41 of Set 9 | santa vitoria do palmar
# Processing Record 42 of Set 9 | kerema
# Processing Record 43 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 9 | iquique
# Processing Record 45 of Set 9 | walvis bay
# Processing Record 46 of Set 9 | ratnagiri
# Processing Record 47 of Set 9 | coquimbo
# Processing Record 48 of Set 9 | manokwari
# Processing Record 49 of Set 9 | necochea
# Processing Record 50 of Set 9 | fenoarivo
# Processing Record 1 of Set 10 | urfa
# City not found. Skipping...
# Processing Record 2 of Set 10 | wau
# Processing Record 3 of Set 10 | erenhot
# Processing Record 4 of Set 10 | bengkulu
# Processing Record 5 of Set 10 | banda aceh
# Processing Record 6 of Set 10 | carutapera
# Processing Record 7 of Set 10 | kalmar
# Processing Record 8 of Set 10 | beringovskiy
# Processing Record 9 of Set 10 | vanavara
# Processing Record 10 of Set 10 | san carlos de bariloche
# Processing Record 11 of Set 10 | nkpor
# Processing Record 12 of Set 10 | progreso
# Processing Record 13 of Set 10 | constantine
# Processing Record 14 of Set 10 | samarai
# Processing Record 15 of Set 10 | tarakan
# Processing Record 16 of Set 10 | worthington
# Processing Record 17 of Set 10 | polunochnoye
# Processing Record 18 of Set 10 | arkhara
# Processing Record 19 of Set 10 | karratha
# Processing Record 20 of Set 10 | pafos
# Processing Record 21 of Set 10 | ninghai
# Processing Record 22 of Set 10 | edd
# Processing Record 23 of Set 10 | dongsheng
# Processing Record 24 of Set 10 | pemangkat
# Processing Record 25 of Set 10 | topchikha
# Processing Record 26 of Set 10 | fairbanks
# Processing Record 27 of Set 10 | kroya
# Processing Record 28 of Set 10 | luxor
# Processing Record 29 of Set 10 | palpa
# Processing Record 30 of Set 10 | beaverlodge
# Processing Record 31 of Set 10 | pareora
# Processing Record 32 of Set 10 | savannah bight
# Processing Record 33 of Set 10 | sao filipe
# Processing Record 34 of Set 10 | tacna
# Processing Record 35 of Set 10 | lakatoro
# Processing Record 36 of Set 10 | palmerston
# Processing Record 37 of Set 10 | san jose
# Processing Record 38 of Set 10 | balurghat
# Processing Record 39 of Set 10 | tolyatti
# Processing Record 40 of Set 10 | iberia
# Processing Record 41 of Set 10 | talaya
# Processing Record 42 of Set 10 | guerrero negro
# Processing Record 43 of Set 10 | akyab
# Processing Record 44 of Set 10 | korla
# Processing Record 45 of Set 10 | opobo
# City not found. Skipping...
# Processing Record 46 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 47 of Set 10 | port macquarie
# Processing Record 48 of Set 10 | nisia floresta
# Processing Record 49 of Set 10 | poum
# Processing Record 50 of Set 10 | derveni
# Processing Record 1 of Set 11 | nhulunbuy
# Processing Record 2 of Set 11 | aripuana
# Processing Record 3 of Set 11 | bintulu
# Processing Record 4 of Set 11 | san martin
# Processing Record 5 of Set 11 | narsaq
# Processing Record 6 of Set 11 | huarmey
# Processing Record 7 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 11 | jalgaon
# Processing Record 9 of Set 11 | tara
# Processing Record 10 of Set 11 | kommunar
# Processing Record 11 of Set 11 | vostok
# Processing Record 12 of Set 11 | manzanillo
# Processing Record 13 of Set 11 | sheltozero
# Processing Record 14 of Set 11 | sa kaeo
# Processing Record 15 of Set 11 | dunmore town
# Processing Record 16 of Set 11 | general roca
# Processing Record 17 of Set 11 | qafsah
# City not found. Skipping...
# Processing Record 18 of Set 11 | aiken
# Processing Record 19 of Set 11 | ladario
# Processing Record 20 of Set 11 | padang
# Processing Record 21 of Set 11 | aklavik
# Processing Record 22 of Set 11 | hami
# Processing Record 23 of Set 11 | guanare
# Processing Record 24 of Set 11 | saryg-sep
# Processing Record 25 of Set 11 | el sauzal
# Processing Record 26 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 27 of Set 11 | san ramon de la nueva oran
# Processing Record 28 of Set 11 | namibe
# Processing Record 29 of Set 11 | yumen
# Processing Record 30 of Set 11 | phek
# Processing Record 31 of Set 11 | nelson bay
# Processing Record 32 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 33 of Set 11 | pasni
# Processing Record 34 of Set 11 | changji
# Processing Record 35 of Set 11 | ixtapa
# Processing Record 36 of Set 11 | charters towers
# Processing Record 37 of Set 11 | gainesville
# Processing Record 38 of Set 11 | wanaka
# Processing Record 39 of Set 11 | vao
# Processing Record 40 of Set 11 | richards bay
# Processing Record 41 of Set 11 | qaqortoq
# Processing Record 42 of Set 11 | caravelas
# Processing Record 43 of Set 11 | poddorye
# Processing Record 44 of Set 11 | ouadda
# Processing Record 45 of Set 11 | tilichiki
# Processing Record 46 of Set 11 | nizhniy ufaley
# Processing Record 47 of Set 11 | reynosa
# Processing Record 48 of Set 11 | maceio
# Processing Record 49 of Set 11 | tommot
# Processing Record 50 of Set 11 | vestmannaeyjar
# Processing Record 1 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 2 of Set 12 | bocanda
# Processing Record 3 of Set 12 | saint-augustin
# Processing Record 4 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 12 | innisfail
# Processing Record 6 of Set 12 | pozo colorado
# Processing Record 7 of Set 12 | aviles
# Processing Record 8 of Set 12 | saint george
# Processing Record 9 of Set 12 | harper
# Processing Record 10 of Set 12 | coahuayana
# Processing Record 11 of Set 12 | bama
# Processing Record 12 of Set 12 | sawakin
# Processing Record 13 of Set 12 | stepnyak
# Processing Record 14 of Set 12 | fethiye
# Processing Record 15 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 16 of Set 12 | mwense
# Processing Record 17 of Set 12 | ambilobe
# Processing Record 18 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 19 of Set 12 | barranca
# Processing Record 20 of Set 12 | corvallis
# Processing Record 21 of Set 12 | bedele
# Processing Record 22 of Set 12 | ban nahin
# Processing Record 23 of Set 12 | kyzyl-suu
# Processing Record 24 of Set 12 | hovd
# Processing Record 25 of Set 12 | caxias
# Processing Record 26 of Set 12 | abu dhabi
# Processing Record 27 of Set 12 | acuna
# City not found. Skipping...
# Processing Record 28 of Set 12 | isangel
# Processing Record 29 of Set 12 | omsukchan
# Processing Record 30 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 12 | east wenatchee bench
# Processing Record 32 of Set 12 | margate
# Processing Record 33 of Set 12 | tagusao
# Processing Record 34 of Set 12 | awjilah
# Processing Record 35 of Set 12 | rabat
# Processing Record 36 of Set 12 | vagay
# Processing Record 37 of Set 12 | nemuro
# Processing Record 38 of Set 12 | sarai sidhu
# Processing Record 39 of Set 12 | bulembu
# Processing Record 40 of Set 12 | lulea
# Processing Record 41 of Set 12 | alekseyevsk
# Processing Record 42 of Set 12 | chengde
# Processing Record 43 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 44 of Set 12 | atasu
# Processing Record 45 of Set 12 | bentiu
# Processing Record 46 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 12 | uk
# City not found. Skipping...
# Processing Record 48 of Set 12 | xuddur
# Processing Record 49 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 12 | sur
# Processing Record 1 of Set 13 | balkhash
# Processing Record 2 of Set 13 | nabire
# Processing Record 3 of Set 13 | jena
# Processing Record 4 of Set 13 | san ignacio
# Processing Record 5 of Set 13 | vigrestad
# Processing Record 6 of Set 13 | ghugus
# Processing Record 7 of Set 13 | sabaudia
# Processing Record 8 of Set 13 | iwanai
# Processing Record 9 of Set 13 | sovetskiy
# Processing Record 10 of Set 13 | brae
# Processing Record 11 of Set 13 | sassandra
# Processing Record 12 of Set 13 | kieta
# Processing Record 13 of Set 13 | port hedland
# Processing Record 14 of Set 13 | auki
# Processing Record 15 of Set 13 | bol
# Processing Record 16 of Set 13 | tateyama
# Processing Record 17 of Set 13 | serra talhada
# Processing Record 18 of Set 13 | masvingo
# Processing Record 19 of Set 13 | palanit
# Processing Record 20 of Set 13 | jalu
# Processing Record 21 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 22 of Set 13 | veraval
# Processing Record 23 of Set 13 | quatre cocos
# Processing Record 24 of Set 13 | guajara-mirim
# City not found. Skipping...
# Processing Record 25 of Set 13 | krasnoselkup
# Processing Record 26 of Set 13 | altamira
# Processing Record 27 of Set 13 | sorong
# Processing Record 28 of Set 13 | leshukonskoye
# Processing Record 29 of Set 13 | luquillo
# Processing Record 30 of Set 13 | mus
# Processing Record 31 of Set 13 | burnie
# Processing Record 32 of Set 13 | okhotsk
# Processing Record 33 of Set 13 | lovington
# Processing Record 34 of Set 13 | riberalta
# Processing Record 35 of Set 13 | potchefstroom
# Processing Record 36 of Set 13 | ponce
# Processing Record 37 of Set 13 | bardsir
# Processing Record 38 of Set 13 | kindu
# Processing Record 39 of Set 13 | vilshofen
# Processing Record 40 of Set 13 | salinopolis
# Processing Record 41 of Set 13 | saint-francois
# Processing Record 42 of Set 13 | altay
# Processing Record 43 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 44 of Set 13 | pabna
# Processing Record 45 of Set 13 | kununurra
# Processing Record 46 of Set 13 | katobu
# Processing Record 47 of Set 13 | ginda
# Processing Record 48 of Set 13 | shingu
# Processing Record 49 of Set 13 | gandajika
# Processing Record 50 of Set 13 | zhigansk
# Processing Record 1 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 14 | tete
# Processing Record 3 of Set 14 | zhuji
# Processing Record 4 of Set 14 | bom jardim
# Processing Record 5 of Set 14 | exokhi
# City not found. Skipping...
# Processing Record 6 of Set 14 | gafanha da encarnacao
# Processing Record 7 of Set 14 | ennis
# Processing Record 8 of Set 14 | damara
# Processing Record 9 of Set 14 | nova friburgo
# Processing Record 10 of Set 14 | pa sang
# Processing Record 11 of Set 14 | mount isa
# Processing Record 12 of Set 14 | ballina
# Processing Record 13 of Set 14 | dunedin
# Processing Record 14 of Set 14 | oksfjord
# Processing Record 15 of Set 14 | moosomin
# Processing Record 16 of Set 14 | tiznit
# Processing Record 17 of Set 14 | kenscoff
# Processing Record 18 of Set 14 | prince rupert
# Processing Record 19 of Set 14 | kudahuvadhoo
# Processing Record 20 of Set 14 | kassiopi
# Processing Record 21 of Set 14 | banchory
# Processing Record 22 of Set 14 | sandpoint
# Processing Record 23 of Set 14 | manjakandriana
# Processing Record 24 of Set 14 | oxchuc
# Processing Record 25 of Set 14 | ibra
# Processing Record 26 of Set 14 | bjornevatn
# Processing Record 27 of Set 14 | asfi
# Processing Record 28 of Set 14 | borba
# Processing Record 29 of Set 14 | uglezavodsk
# Processing Record 30 of Set 14 | plettenberg bay
# Processing Record 31 of Set 14 | gracac
# Processing Record 32 of Set 14 | dali
# Processing Record 33 of Set 14 | brandon
# Processing Record 34 of Set 14 | mayumba
# Processing Record 35 of Set 14 | dzerzhinskoye
# Processing Record 36 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 37 of Set 14 | sretensk
# Processing Record 38 of Set 14 | misratah
# Processing Record 39 of Set 14 | soto la marina
# Processing Record 40 of Set 14 | hokitika
# Processing Record 41 of Set 14 | kirillov
# Processing Record 42 of Set 14 | dryden
# Processing Record 43 of Set 14 | gelibolu
# Processing Record 44 of Set 14 | oum hadjer
# Processing Record 45 of Set 14 | high level
# Processing Record 46 of Set 14 | baruun-urt
# Processing Record 47 of Set 14 | sulangan
# Processing Record 48 of Set 14 | celestun
# Processing Record 49 of Set 14 | tokat
# Processing Record 50 of Set 14 | harbour breton
# Processing Record 1 of Set 15 | ayios kirikos
# City not found. Skipping...
# Processing Record 2 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 15 | fortuna foothills
# Processing Record 4 of Set 15 | uvira
# Processing Record 5 of Set 15 | bambous virieux
# Processing Record 6 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 15 | dzaoudzi
# Processing Record 8 of Set 15 | shakawe
# Processing Record 9 of Set 15 | gazli
# Processing Record 10 of Set 15 | alta floresta
# Processing Record 11 of Set 15 | tupiza
# Processing Record 12 of Set 15 | pangnirtung
# Processing Record 13 of Set 15 | esfahan
# Processing Record 14 of Set 15 | raudeberg
# Processing Record 15 of Set 15 | elliot lake
# Processing Record 16 of Set 15 | ucluelet
# Processing Record 17 of Set 15 | new iberia
# Processing Record 18 of Set 15 | yeppoon
# Processing Record 19 of Set 15 | petukhovo
# Processing Record 20 of Set 15 | vytegra
# Processing Record 21 of Set 15 | sept-iles
# Processing Record 22 of Set 15 | coldwater
# Processing Record 23 of Set 15 | haines junction
# Processing Record 24 of Set 15 | zbarazh
# Processing Record 25 of Set 15 | mildura
# Processing Record 26 of Set 15 | praia da vitoria
# Processing Record 27 of Set 15 | acajutla
# Processing Record 28 of Set 15 | tabou
# Processing Record 29 of Set 15 | ville-marie
# Processing Record 30 of Set 15 | onverwacht
# Processing Record 31 of Set 15 | eureka
# Processing Record 32 of Set 15 | hutchinson
# Processing Record 33 of Set 15 | gijon
# Processing Record 34 of Set 15 | sainte-marie
# Processing Record 35 of Set 15 | gobabis
# Processing Record 36 of Set 15 | tignere
# Processing Record 37 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 39 of Set 15 | tomatlan
# Processing Record 40 of Set 15 | sabha
# Processing Record 41 of Set 15 | bosaso
# Processing Record 42 of Set 15 | sisimiut
# Processing Record 43 of Set 15 | quelimane
# Processing Record 44 of Set 15 | enid
# Processing Record 45 of Set 15 | tucuman
# Processing Record 46 of Set 15 | balsas
# Processing Record 47 of Set 15 | popondetta
# Processing Record 48 of Set 15 | novoye leushino
# Processing Record 49 of Set 15 | atbasar
# Processing Record 50 of Set 15 | agadir
# Processing Record 1 of Set 16 | mattawa
# Processing Record 2 of Set 16 | sandnessjoen
# Processing Record 3 of Set 16 | farias brito
# Processing Record 4 of Set 16 | hofn
# Processing Record 5 of Set 16 | vagur
# Processing Record 6 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 16 | houma
# Processing Record 8 of Set 16 | ikalamavony
# Processing Record 9 of Set 16 | yerbogachen
# Processing Record 10 of Set 16 | daru
# Processing Record 11 of Set 16 | deh rawud
# City not found. Skipping...
# Processing Record 12 of Set 16 | kruisfontein
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 690

# %%
# 7 Add the data to a new DataFrame.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Nikolskoye      RU  59.7035   30.7861     32.81        82          62
# 1         Bluff      NZ -46.6000  168.3333     53.80        57          93
# 2      Thompson      CA  55.7435  -97.8558     24.96        42         100
# 3      Kirakira      SB -10.4544  161.9205     85.57        62          91
# 4  Puerto Ayora      EC  -0.7393  -90.3518     75.40        91          79
# 5    Whitehorse      CA  60.7161 -135.0538     34.57        51         100
# 6  Punta Arenas      CL -53.1500  -70.9167     46.51        81          40
# 7       Kahului      US  20.8947 -156.4700     80.62        44          20
# 8   East London      ZA -33.0153   27.9116     61.38        77         100
# 9        Sarana      RU  56.4773   57.7259     29.07        87         100
#
#    Wind Speed Current Description
# 0        3.20       broken clouds
# 1        8.01     overcast clouds
# 2        5.75     overcast clouds
# 3        5.86          light rain
# 4        5.32       broken clouds
# 5       10.36     overcast clouds
# 6       13.80    scattered clouds
# 7       14.97          few clouds
# 8        6.06     overcast clouds
# 9        1.32     overcast clouds

# %%
# 8 Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
